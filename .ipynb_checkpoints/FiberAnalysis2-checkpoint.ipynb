# %% [markdown]
# ## Hi
# Making namespaces
# > also this is a cheat sheet https://www.markdownguide.org/cheat-sheet/

# %%
#Hi
import csv
import pandas as pd
import glob
import os
from io import StringIO
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy.signal import savgol_filter
from scipy import signal
import seaborn as sns
import math
# Apply the default theme




from tkinter import Tk
from tkinter.filedialog import askdirectory
path = askdirectory(title='Select Folder') # shows dialog box and return the path
os.path.abspath(path)
files = glob.glob(os.path.join(path, "*.txt"))
path1 = os.path.basename(os.path.normpath(path))


#########################################################################################  #########################################################################################    
#style guidelines for Seaborne
sns.set(rc={"xtick.top" : True, "ytick.right" : True})
sns.set_theme()  
sns.set_style(style='white')
sns.set_style("ticks")

sns.set_style({"xtick.direction": "in","ytick.direction": "in"})


#########################################################################################  #########################################################################################

# %% [markdown]
# ## function defining + classes

# %%
#some COOL functions
#test to see if we can go through a file
def turnCsvIntoDF(fullfile):
    df = pd.read_csv(fullfile, sep = "\t")
    
    
    return df
#take the file name and returns a unique name, plus relevant identifiers:
#relevant ident is: Sample name, temperature, Spinning speed, flowrate
#Returns as a TUPLE: (FullName, [Sample name, temperature, Denier, flowrate, spinning speed])
def returnName(filename):
    file1 = filename.replace(".txt","")
    NameInfo = file1.split("-")
    #print(NameInfo)
    thing = ""
    for idx, i in enumerate(NameInfo):
        if not idx == 2: 
            if not idx == 0:
                thing += "-"
            thing += i
    #print(NameInfo)    
    #print(thing)
    return (thing, NameInfo)
        

###################################
#Some classes

#holds data for each data point
#Takes in a dataframe and name
#identifierinfo is [Sample name, temperature, Denier, flowrate, spinning speed]
class dfData:
    def __init__(self, name, path1, indentifierInfo,filename):
        self.name = name 
        self.indentifierInfo = indentifierInfo
        self.df = turnCsvIntoDF(path1 +"/" +filename)
        #print(self.df)
        self.dfstatistics = self.statisticalAnalysis()
        
        
        
    def returnName(self):
        return self.name
    def returnIndet(self):
        return self.indentifierInfo
    def returnStat(self):
        return self.dfstatistics
    
    #returns Statistical data for certain params as seen below, as mean and stv
    def statisticalAnalysis(self):
        self.df = self.df[self.df["%Area"]<95].copy()
        self.length = self.df.shape[0]
        self.dfmean = pd.DataFrame(self.df.mean()).transpose()[["Area","Circ.","%Area","AR","Round","MinFeret"]].copy()
        
        self.dfstd = pd.DataFrame(self.df.std()).transpose()[["Area","Circ.","%Area","AR","Round","MinFeret"]].copy()
        #self.dfstd.rename(columns={"Area":"AreaSTD","Circ.":"CircSTD","%Area":"%AreaSTD","AR":"ARSTD","Round":"RoundSTD","MinFeret":"MinFeretSTD"}, inplace = True)
        
        self.dfFULL = self.dfmean.join(self.dfstd, lsuffix = "", rsuffix = "_std")
        #print(self.indentifierInfo)
        self.ident = pd.DataFrame([self.indentifierInfo], columns = ["Sample","Temperature","Denier","Flowrate","Spinning Speed"])
        self.ident["Name"] = self.indentifierInfo[0]+"-"+self.indentifierInfo[1]
        self.ident["n"] = self.length
        #print(self.ident)
        self.dfFULL = self.dfFULL.join(self.ident)
        self.dfFULL["95confidence"] = self.dfFULL["%Area_std"]/np.sqrt(self.dfFULL["n"])*1.96
        self.dfFULL = self.dfFULL.apply(pd.to_numeric, errors='ignore')
        #print(self.dfFULL.dtypes)
         
        return self.dfFULL
        
#Holds the DF data, and calls operations on the df Data
class dfHolder:
    def __init__(self):
        self.dictionRheo = {}
        self.rheoData = pd.read_csv("./RelaxationTimeCalcs.csv")
        
        print(self.rheoData)
        
    #Adds a dfdata to a dictionary
    def addValue(self, filename, path):
        self.nameTuple = returnName(filename)
        self.path1 = path
        #print(self.nameTuple[1])
        self.dictionRheo[self.nameTuple[0]] = dfData(self.nameTuple[0], self.path1, self.nameTuple[1], filename)
        
        
    #gives DF of values we have: 
    #form: Hash key, PP type, temp, denier, flowrate, spinning speed
    def dfReturn(self):
        self.dfMaker = []
        for i in self.dictionRheo:
            self.name1 = [self.dictionRheo[i].returnName()]
            #print(self.name1)
            self.nameinfo = self.dictionRheo[i].returnIndet()
            self.name1.extend(self.nameinfo)
            
            self.dfMaker.append(self.name1)
            
        self.columns = ['HashKey', 'PPtype', 'Temp', 'Denier', 'Flowrate', 'SpinningSpeed']
        self.dfFull = pd.DataFrame(self.dfMaker,columns = self.columns)
        #print(self.dfFull)
        return self.dfFull
    
    def returnStasticialValues(self):
        self.totalStat = []
        for i in self.dictionRheo:
            self.totalStat.append(self.dictionRheo[i].returnStat())
            
        self.totalDf = pd.concat(self.totalStat).reset_index()
        
        
        #print(self.totalDf)
        #print(self.rheoData)
        self.rheoData["Name"] = self.rheoData["Ident.1"]
        
        self.returned = pd.merge(self.totalDf,self.rheoData, on = "Name")
        
        return self.returned
    
    def dfStatReturn(self, identifier):
        return self.dictionRheo[identifier].statisticalAnalysis()
            
    def printKeys(self):
        return self.dictionRheo.keys()

# %% [markdown]
# ## Class init

# %% [markdown]
# ## HELLO, this is for parsing through the data
# >We are also initializing here

# %%
#########################################################################################  #########################################################################################    
#some intializiation
#THESE SHOULD BE DICTIONARIES, CHECK INTO THIS
vStrain = []
vRate = []
strains = [100,10,1]
loadings = []
pdmstype = []
blerp = dfHolder()
#########################################################################################  #########################################################################################    



for path, dirs, files in os.walk(path):
    print("Path:", path)

    print ("\nDirs:")
    for d in dirs:
        print ('\t'+d)

    
        
    print ("\nFiles:")  
    

    for f in files:
        
        filename = os.path.basename(f)
        
        
        if(filename.endswith('.txt')):
            fullfile = path +"/" +filename
            print(fullfile)
            returnName(filename)
        
            blerp.addValue(filename, path)
           
            
            
            

            
            #plotData(data1,name, n)
           
                


    
        
        
        
        
    print("Finished for loop")
       

        
        
    print ("----")
    
splerp = pd.read_csv("./35denierFiberData.csv")
print(splerp)
dfTotal = blerp.dfReturn()

#print(blerp.printKeys())
# Out:
#        Ident  Unnamed: 1                        Filename Sample Name  \
# 0   3155-210         NaN                             NaN        3155
# 1   3155-230         8.0        PP3155_230_1-17-22_S1_p2        3155
# 2     M1-210        17.0              S1-210-PP-02072022          S1
# 3     M1-230        19.0         S1_230_Sample1_01212022          S1
# 4     M1-250        18.0              S1-250-PP-02082022          S1
# 5     M2-210        20.0            S2-210-PP-02072022-2          S2
# 6     M2-250        21.0              S2-250-PP-02082022          S2
# 7     M3-210        23.0              S3-210-S3-03082022          S3
# 8     M3-230        26.0         S3_230_Sample1_01212022          S3
# 9     M3-250        24.0             S3-250-S10-03082022          S3
# 10    M4-210        27.0              S4-210-PP-02072022          S4
# 11    M4-230        29.0             S4_Sample1_01212022          S4
# 12    M4-250        28.0          S4-250-PP-02082022 (1)          S4
# 13    M5-210        30.0          S5-210-PP-02072022 (1)          S5
# 14    M5-230        32.0         S5_230_Sample1_01212022          S5
# 15    M5-250        31.0              S5-250-PP-02082022          S5
# 16    P1-210         0.0            3854-210-PP-02072022        3854
# 17    P1-230        10.0     PP3854_230_Sample1_01212022        3854
# 18    P1-250         9.0          PP3854-250-PP-02082022        3854
# 19    P2-210        11.0          PP3865-210-PP-02072022        3865
# 20    P2-230        12.0     PP3865_230_sample1_01242022        3865
# 21    P2-250         1.0            3865-250-PP-02082022        3865
# 22    P3-210        14.0        PPCP360H-210-PP-02072022      CP360H
# 23    P3-230        13.0   PPCP360A_230_sample1_01242022      CP360H
# 24    P3-250         2.0          CP360H-250-PP-02082022      CP360H
# 25    P4-210         3.0       D115A-210-PP-02072022 (1)       D115A
# 26    P4-230        15.0    PPD115A_230_sample1_01242022       D115A
# 27    P4-250         4.0           D115A-250-PP-02082022       D115A
# 28    P5-210         5.0          GPH100-210-PP-02072022      GPH100
# 29    P5-230        16.0  PPGPH100A_230_sample1_01242022      GPH100
# 30    P5-250         6.0          GPH100-250-PP-02082022      GPH100
#
#     Zero Shear viscosity  Relaxation Time  Temperature       Gc     Gpps  \
# 0              373.00000         0.001592          210      NaN      NaN
# 1              159.92300         0.000764          230  0.02898  0.90979
# 2              352.30120         0.001690          210  0.03981  0.89686
# 3              221.42957         0.000914          230  0.04369  0.93236
# 4              127.18688         0.000793          250  0.03738  0.95899
# 5              498.01833         0.002240          210  0.03413  0.82188
# 6              132.98133         0.000932          250  0.02960  0.92658
# 7              332.52400         0.001930          210  0.03041  0.84724
# 8              389.55350         0.002080          230  0.03067  0.83557
# 9              202.39125         0.000987          250  0.03004  0.88421
# 10             465.46250         0.002550          210  0.02760  0.80201
# 11             396.78833         0.002300          230  0.02586  0.81336
# 12             242.40500         0.001080          250  0.02796  0.85029
# 13             315.04317         0.001600          210  0.04169  0.91881
# 14             225.40883         0.001030          230  0.04607  0.94584
# 15             145.54600         0.000567          250  0.05013  0.96589
# 16             355.65129         0.001650          210  0.04607  0.92053
# 17             247.67687         0.001060          230  0.04893  0.94775
# 18             164.21600         0.000518          250  0.05307  0.96571
# 19             240.38480         0.001210          210  0.03473  0.89393
# 20             141.89929         0.000651          230  0.03754  0.93457
# 21             115.00080         0.000420          250  0.03891  0.94596
# 22             321.75117         0.001580          210  0.03692  0.88284
# 23             219.69367         0.001050          230  0.03729  0.91463
# 24             146.22950         0.000859          250  0.03435  0.93934
# 25            1024.69500         0.005670          210  0.02626  0.71695
# 26             544.71767         0.003120          230  0.02716  0.79326
# 27             355.70867         0.001940          250  0.02734  0.82960
# 28             133.01880         0.000991          210  0.02299  0.89069
# 29             100.81920         0.000827          230  0.02242  0.90627
# 30              44.99010         0.000393          250  0.02204  0.95736
#
#         Gps SampleName   Ident.1  Polydispersity Index
# 0       NaN       3155  3155-210                   NaN
# 1   1.55361       3155  3155-230               3.45021
# 2   1.51713         M1    M1-210               2.51174
# 3   1.61530         M1    M1-230               2.28894
# 4   1.70231         M1    M1-250               2.67504
# 5   1.26397         M2    M2-210               2.93002
# 6   1.49253         M2    M2-250               3.37819
# 7   1.27785         M3    M3-210               3.28872
# 8   1.26668         M3    M3-230               3.26081
# 9   1.36154         M3    M3-250               3.32904
# 10  1.18783         M4    M4-210               3.62339
# 11  1.22089         M4    M4-230               3.86697
# 12  1.28164         M4    M4-250               3.57709
# 13  1.58393         M5    M5-210               2.39853
# 14  1.65672         M5    M5-230               2.17084
# 15  1.72520         M5    M5-250               1.99487
# 16  1.61574         P1    P1-210               2.17038
# 17  1.70917         P1    P1-230               2.04355
# 18  1.75975         P1    P1-250               1.88423
# 19  1.45234         P2    P2-210               2.87948
# 20  1.56070         P2    P2-230               2.66372
# 21  1.63352         P2    P2-250               2.57006
# 22  1.44675         P3    P3-210               2.70857
# 23  1.54333         P3    P3-230               2.68186
# 24  1.63133         P3    P3-250               2.91124
# 25  1.06384         P4    P4-210               3.80812
# 26  1.19911         P4    P4-230               3.68220
# 27  1.25024         P4    P4-250               3.65774
# 28  1.38218         P5    P5-210               4.34901
# 29  1.42065         P5    P5-230               4.45962
# 30  1.54961         P5    P5-250               4.53719
# Path: C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3
#
# Dirs:
#
# Files:
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-210-0.75-0.17-1958.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-210-1.5-0.33-1798.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-210-1.75-0.17-1007.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-210-2.5-0.17-764.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-210-2.5-0.33-1366.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-210-2.5-0.41-1703.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-210-3.5-0.17-503.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-210-3.5-0.33-976.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-210-3.5-0.41-1216.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-230-0.9-0.17-1918.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-230-1.75-0.17-986.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-230-1.9-0.33-1802.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-230-2.5-0.17-690.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-230-2.5-0.33-1369.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-230-2.5-0.41-1736.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-230-3.5-0.17-493.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-230-3.5-0.33-978.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/3155-230-3.5-0.41-1240.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M3-230-1.9-0.33-1865.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M3-230-2.5-0.33-1417.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-210-1.0-0.17-2000.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-210-1.75-0.17-1152.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-210-1.9-0.33-1567.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-210-2.5-0.17-806.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-210-2.5-0.33-1214.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-210-2.5-0.41-1645.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-210-3.5-0.17-576.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-210-3.5-0.33-867.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-210-3.5-0.41-1175.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-230-0.9-0.17-1892.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-230-1.75-0.17-973.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-230-2.5-0.17-681.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-230-2.5-0.41-1791.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-230-3.5-0.17-487.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-230-3.5-0.33-1012.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M4-230-3.5-0.41-1279..txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-210-0.9-0.17-1965.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-210-1.75-0.17-1010.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-210-1.9-0.33-1770.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-210-2.5-0.33-1345.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-210-2.5-0.41-1686.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-210-3.5-0.17-505.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-210-3.5-0.33-961.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-210-3.5-0.41-1206.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-230-0.9-0.17-1884.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-230-1.75-0.17-968.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-230-1.9-0.33-1822.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-230-2.5-0.17-678.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-230-2.5-0.33-1385.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-230-2.5-0.41-1726.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-230-3.5-0.17-484.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-230-3.5-0.33-989.txt
# C:/Users/Himendra/Documents/sdfsdf/AnalysisForCFD/AnalysisForCFD/ImageAnalysis2/outputset3/M5-230-3.5-0.41-1233.txt
# Finished for loop
# ----
#               Filename  Number of Samples Polymer Type  Temperature  \
# 0      M1-210-0,17@437                 42           M1          210
# 1   M1-210-0,25@643CFD                 34           M1          210
# 2      M1-210-0,33@848                 33           M1          210
# 3     M1-210-0,41@1054                 40           M1          210
# 4      P2-210-0,33@848                 43           P2          210
# ..                 ...                ...          ...          ...
# 69     P3-250-0,11@282                 36           P3          250
# 70     P3-250-0,17@437                 39           P3          250
# 71     P3-250-0,25@643                 32           P3          250
# 72     P3-250-0,33@848                 35           P3          250
# 73    P3-250-0,41@1054                 31           P3          250
#
#     Spinning Speed  Sample  Was CFD? Identifier  Zero Shear Viscosity  \
# 0             0.17       1         0     M1-210              352.3012
# 1             0.25       2         1     M1-210              352.3012
# 2             0.33       3         0     M1-210              352.3012
# 3             0.41       4         0     M1-210              352.3012
# 4             0.33      58         0     P2-210              240.3848
# ..             ...     ...       ...        ...                   ...
# 69            0.11      72         0     P3-250              146.2295
# 70            0.17      73         0     P3-250              146.2295
# 71            0.25      74         0     P3-250              146.2295
# 72            0.33      75         0     P3-250              146.2295
# 73            0.41      76         0     P3-250              146.2295
#
#     Relaxation Time  ...  Stdev Area  Threshold   Hollow  Average Solid Fract  \
# 0          0.001690  ...    73.89511      0.740  0.17552              0.82448
# 1          0.001690  ...    62.72260      0.705  0.21544              0.78456
# 2          0.001690  ...    78.65067      0.700  0.22133              0.77867
# 3          0.001690  ...    45.76545      0.710  0.22770              0.77230
# 4          0.001210  ...    59.71045      0.735  0.19660              0.80340
# ..              ...  ...         ...        ...      ...                  ...
# 69         0.000859  ...    90.97322      0.815  0.10053              0.89947
# 70         0.000859  ...    84.63493      0.815  0.11115              0.88885
# 71         0.000859  ...    75.62396      0.825  0.10131              0.89869
# 72         0.000859  ...    85.29134      0.820  0.10749              0.89251
# 73         0.000859  ...    64.22455      0.810  0.11361              0.88639
#
#     Stdev Solid Fract  standard error of mean    guess     error   squares  \
# 0             0.03535                 0.01069  0.20891  0.001110  0.000191
# 1             0.00814                 0.00274  0.23490  0.000379  0.002890
# 2             0.02780                 0.00949  0.24718  0.000668  0.003550
# 3             0.00945                 0.00293  0.24575  0.000326  0.004350
# 4             0.00764                 0.00228  0.18239  0.000202  0.001220
# ..                ...                     ...      ...       ...       ...
# 69            0.01333                 0.00436  0.12580  0.000639  0.003740
# 70            0.01171                 0.00368  0.13336  0.000493  0.002560
# 71            0.01107                 0.00383  0.14034  0.001520  0.003650
# 72            0.00730                 0.00242  0.14380  0.001320  0.002940
# 73            0.01256                 0.00442  0.14372  0.000906  0.002310
#
#     Why masked?
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 69          NaN
# 70          NaN
# 71          NaN
# 72          NaN
# 73          NaN
#
# [74 rows x 28 columns]

# %%
data = blerp.returnStasticialValues()
print(data.dtypes)
data["Hollow"] = 100-data["%Area"]
data["Temperature (C)"] = data["Temperature_y"]
data["Flowrate (ghm)"] = data["Flowrate"]
#data.to_csv("thing.csv")

#print(data)
#data = data[(data.Flowrate <0.40)]#&(data.Flowrate <0.40)]#
#data = data[(data.Flowrate >0.19)&(data.Flowrate <0.40)]
sns.set(rc={"xtick.top" : True, "ytick.right" : True},font_scale = 20)
sns.set_theme()  
sns.set_style(style='white')
sns.set_style("ticks")


sns.set_style({"xtick.direction": "in","ytick.direction": "in"})
plt.figure(figsize = (6,6), dpi = 1800)
#have to do 2 different ifs due to two different datatypes with diff variables names
"""a1 = sns.relplot(
    data=data, kind = "line",
    x="Relaxation Time", y="Hollow",  markers = True, linewidth = 2,markersize=10,
     ci = False,markeredgecolor='none', palette = "crest",facet_kws=dict(despine=False)
    );"""

a1 = sns.relplot(
    data=data1, kind = "scatter", col = "Flowrate (ghm)",
    x="Area", y="Denier", hue = "Flowrate (ghm)",  palette = "flare",facet_kws=dict(despine=False), s = 300, edgecolor = "black"
    );
#a1.set_titles("")
a1.set_axis_labels( "Relaxation Time (s)",  "Hollow (%)", fontsize = 20)

for ax in a1.axes.ravel():
        
        ax.tick_params(which="both", right=True, labelsize = 15)
        ax.tick_params(which="both", top=True)
        ax.tick_params(which = "both",left=True, labelsize = 15)
#a1.set_axis_labels("Linear Density [Denier]", "Hollownes (%)", fontsize = 20)
#a1.map(plt.errorbar,"Spinning Speed","%Area","%Area_std", linestyle = "")
#a1.set(xscale="log",yscale="log")
plt.tick_params(which = 'both', right=True,top=True)

        #df_melted = pd.melt(df,id_vars=["NormalizedStrainRate-Smoothed"], value_vars=["NormalizedElasticStress-Smoothed","NormalizedStress-Smoothed"])
    #a1.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=False)
    #a1.set(xlabel=None,ylabel=None,yticklabels=[],xticklabels=[])
a1.savefig("fullrelax.png")
plt.show()
plt.clf()
# Out:
# index                     int64
# Area                    float64
# Circ.                   float64
# %Area                   float64
# AR                      float64
# Round                   float64
# MinFeret                float64
# Area_std                float64
# Circ._std               float64
# %Area_std               float64
# AR_std                  float64
# Round_std               float64
# MinFeret_std            float64
# Sample                   object
# Temperature_x             int64
# Denier                  float64
# Flowrate                float64
# Spinning Speed          float64
# Name                     object
# n                         int64
# 95confidence            float64
# Ident                    object
# Unnamed: 1              float64
# Filename                 object
# Sample Name              object
# Zero Shear viscosity    float64
# Relaxation Time         float64
# Temperature_y             int64
# Gc                      float64
# Gpps                    float64
# Gps                     float64
# SampleName               object
# Ident.1                  object
# Polydispersity Index    float64
# dtype: object
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 27
#      19 #have to do 2 different ifs due to two different datatypes with diff variables names
#      20 """a1 = sns.relplot(
#      21     data=data, kind = "line",
#      22     x="Relaxation Time", y="Hollow",  markers = True, linewidth = 2,markersize=10,
#      23      ci = False,markeredgecolor='none', palette = "crest",facet_kws=dict(despine=False)
#      24     );"""
#      26 a1 = sns.relplot(
# ---> 27     data=data1, kind = "scatter", col = "Flowrate (ghm)",
#      28     x="Area", y="Denier", hue = "Flowrate (ghm)",  palette = "flare",facet_kws=dict(despine=False), s = 300, edgecolor = "black"
#      29     );
#      30 #a1.set_titles("")
#      31 a1.set_axis_labels( "Relaxation Time (s)",  "Hollow (%)", fontsize = 20)
#
# NameError: name 'data1' is not defined

# %%
RelaxCalcs = pd.read_csv("./RelaxationTimeCalcs.csv")
#print(RelaxCalcs)
RelaxCalcs["Relaxation Time"] = RelaxCalcs["Relaxation Time"]/0.159155
RelaxCalcs["Color"] = 1
plt.figure(figsize = (6,6), dpi = 1800)
#have to do 2 different ifs due to two different datatypes with diff variables names
a5 = sns.relplot(
    data=RelaxCalcs, kind = "scatter",
    x="Zero Shear viscosity", y="Relaxation Time",  s = 200, edgecolor = "black", hue = "Color", #markers = True, linewidth = 2,markersize=10, #style = "Temperature (C)", hue = "Flowrate (g/h/m)", col = "SampleName", col_wrap = 2,
      palette = "flare",facet_kws=dict(despine=False), aspect = 1.15
    );

#a1.set_titles("")
#a2.set_axis_labels( "Relaxation Time (s)",  "Hollow (%)", fontsize = 20)

for ax in a5.axes.ravel():
        
        ax.tick_params(which="both", right=True, labelsize = 15)
        ax.tick_params(which="both", top=True)
        ax.tick_params(which = "both",left=True, labelsize = 15)

a5.set_axis_labels("Zero Shear Viscosity (Pa*s)", "Relaxation Time (s)", fontsize = 20)
#a1.map(plt.errorbar,"Spinning Speed","%Area","%Area_std", linestyle = "")
#a1.set(xscale="log",yscale="log")
#plt.tick_params(which = 'both', right=True,top=True)
#a5.set(xlim=(0.5,4.0),ylim=(11,31))
        #df_melted = pd.melt(df,id_vars=["NormalizedStrainRate-Smoothed"], value_vars=["NormalizedElasticStress-Smoothed","NormalizedStress-Smoothed"])
    #a1.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=False)
    #a1.set(xlabel=None,ylabel=None,yticklabels=[],xticklabels=[])
nameSave = "I:/My Drive/Research/NWI/Final Paper/RawData/RawFigures/RelaxationGraph"
a5.savefig(nameSave, dpi = 800)
plt.show()
plt.clf()

# %%
#print(data)
#data = data[(data.Flowrate <0.40)]#&(data.Flowrate <0.40)]#
#data = data[(data.Flowrate >0.19)&(data.Flowrate <0.40)]
sns.set(rc={"xtick.top" : True, "ytick.right" : True},font_scale = 20)
sns.set_theme()  
sns.set_style(style='white')
sns.set_style("ticks")
nameID = "M5"
data1 = data[(data.SampleName == nameID)]
data1["Temperature (C)"] = data1["Temperature_y"]
data1["Flowrate (g/h/m)"] = data1["Flowrate"]
sns.set_style({"xtick.direction": "in","ytick.direction": "in"})
plt.figure(figsize = (6,6), dpi = 1800)
#have to do 2 different ifs due to two different datatypes with diff variables names
a2 = sns.relplot(
    data=data1, kind = "line",
    x="Denier", y="Hollow",  markers = True, linewidth = 2,markersize=10, style = "Temperature (C)", hue = "Flowrate (g/h/m)", col = "SampleName", col_wrap = 2,
     ci = False,markeredgecolor='none', palette = "flare",facet_kws=dict(despine=False)
    );


#a1.set_titles("")
#a2.set_axis_labels( "Relaxation Time (s)",  "Hollow (%)", fontsize = 20)

for ax in a2.axes.ravel():
        
        ax.tick_params(which="both", right=True, labelsize = 15)
        ax.tick_params(which="both", top=True)
        ax.tick_params(which = "both",left=True, labelsize = 15)

a2.set_axis_labels("Linear Density [Denier]", "Hollownes (%)", fontsize = 20)
#a1.map(plt.errorbar,"Spinning Speed","%Area","%Area_std", linestyle = "")
#a1.set(xscale="log",yscale="log")
plt.tick_params(which = 'both', right=True,top=True)
a2.set(xlim=(0.5,4.0),ylim=(11,31))
        #df_melted = pd.melt(df,id_vars=["NormalizedStrainRate-Smoothed"], value_vars=["NormalizedElasticStress-Smoothed","NormalizedStress-Smoothed"])
    #a1.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=False)
    #a1.set(xlabel=None,ylabel=None,yticklabels=[],xticklabels=[])
nameSave = nameID+".png"
a2.savefig(nameSave, dpi = 800)
plt.show()
plt.clf()
# Out:
# C:\Users\Himendra\AppData\Local\Temp\ipykernel_18588\1179929841.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["Temperature (C)"] = data1["Temperature_y"]
# C:\Users\Himendra\AppData\Local\Temp\ipykernel_18588\1179929841.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["Flowrate (g/h/m)"] = data1["Flowrate"]
# F:\AnacondaCode\envs\Pandas\lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.set(rc={"xtick.top" : True, "ytick.right" : True},font_scale = 20)
sns.set_theme()  
sns.set_style(style='white')
sns.set_style("ticks")

data["processtime"] = 0.029670358/data["Flowrate"]
data["nonDimTime"] = data["Relaxation Time"]/data["processtime"]
data["truearea"] = data["Area"]/data["%Area"]
#data["Hollow"] = data["Hollow"]*100
data = data[(data.Denier == 3.5)]
print(data)

sns.set_style({"xtick.direction": "in","ytick.direction": "in"})
plt.figure(figsize = (6,6), dpi = 1000)
#have to do 2 different ifs due to two different datatypes with diff variables names
"""a1 = sns.relplot(
    data=data, kind = "line",
    x="Relaxation Time", y="Hollow",  markers = True, linewidth = 2,markersize=10,
     ci = False,markeredgecolor='none', palette = "crest",facet_kws=dict(despine=False)
    );"""

a1 = sns.relplot(
    data=data, kind = "scatter", col = "Denier",
    x="nonDimTime", y="Area", hue = "Flowrate (ghm)",  palette = "flare",facet_kws=dict(despine=False), s = 300, edgecolor = "black"
    );
#a1.set_titles("")
a1.set_axis_labels( "Relaxation Time (s)",  "Hollow (%)", fontsize = 20)

for ax in a1.axes.ravel():
        
        ax.tick_params(which="both", right=True, labelsize = 15)
        ax.tick_params(which="both", top=True)
        ax.tick_params(which = "both",left=True, labelsize = 15)
#a1.set_axis_labels("Linear Density [Denier]", "Hollownes (%)", fontsize = 20)
#a1.map(plt.errorbar,"Spinning Speed","%Area","%Area_std", linestyle = "")
#a1.set(xscale="log",yscale="log")
plt.tick_params(which = 'both', right=True,top=True)

        #df_melted = pd.melt(df,id_vars=["NormalizedStrainRate-Smoothed"], value_vars=["NormalizedElasticStress-Smoothed","NormalizedStress-Smoothed"])
    #a1.despine(top=True, right=True, left=True, bottom=True, offset=None, trim=False)
    #a1.set(xlabel=None,ylabel=None,yticklabels=[],xticklabels=[])
a1.savefig("I:/My Drive/Research/NWI/Final Paper/RawData/RawFigures/35denierfromFinalarea.png", dpi = 800)
plt.show()
plt.clf()
# Out:
#     index        Area     Circ.      %Area        AR     Round   MinFeret  \
# 6       0  461.379711  0.853410  86.240759  1.073904  0.938096  23.274133
# 7       0  428.459790  0.845600  82.642950  1.116150  0.901800  22.216610
# 8       0  437.376112  0.833697  80.874955  1.099618  0.911461  22.620101
# 17      0  407.126809  0.883455  71.342209  1.061273  0.943836  21.758027
# 18      0  602.972095  0.856838  70.551351  1.045824  0.957297  26.505446
# 19      0  516.321275  0.876220  72.441879  1.059835  0.949341  24.538791
# 24      0  496.485670  0.868143  77.920659  1.035231  0.966571  24.493341
# 25      0  440.806716  0.884621  76.664316  1.035221  0.966968  22.983432
# 26      0  439.705327  0.886133  75.412653  1.045684  0.957286  22.896245
# 32      0  548.833239  0.871746  73.825268  1.099732  0.911423  25.015704
# 33      0  322.266260  0.828854  73.341488  1.163976  0.866423  18.032138
# 34      0  499.890603  0.832044  73.518706  1.198147  0.841779  23.000412
# 41      0  369.005982  0.869349  85.570725  1.045009  0.959183  21.094367
# 42      0  426.531272  0.870049  81.615524  1.059117  0.944942  22.643718
# 43      0  430.452600  0.839860  80.200710  1.068540  0.937230  22.719330
#
#       Area_std  Circ._std  %Area_std  ...      Gps  SampleName   Ident.1  \
# 6   151.333684   0.054440   3.202976  ...  1.55361        3155  3155-230
# 7    58.416421   0.049342   2.046816  ...  1.55361        3155  3155-230
# 8    46.709219   0.057332   2.660082  ...  1.55361        3155  3155-230
# 17  138.262030   0.017065   1.366733  ...  1.18783          M4    M4-210
# 18  198.004476   0.048972   2.741044  ...  1.18783          M4    M4-210
# 19  145.885383   0.033013   2.617347  ...  1.18783          M4    M4-210
# 24  116.872979   0.036049   1.013516  ...  1.22089          M4    M4-230
# 25   86.999199   0.041521   2.468180  ...  1.22089          M4    M4-230
# 26   61.329439   0.024654   1.339082  ...  1.22089          M4    M4-230
# 32  204.344188   0.026455   2.255707  ...  1.58393          M5    M5-210
# 33  232.845488   0.046867   3.287628  ...  1.58393          M5    M5-210
# 34  187.589514   0.050864   2.578922  ...  1.58393          M5    M5-210
# 41   84.133213   0.035071   1.785564  ...  1.65672          M5    M5-230
# 42   60.378608   0.029109   1.620166  ...  1.65672          M5    M5-230
# 43   50.741432   0.065488   1.828830  ...  1.65672          M5    M5-230
#
#    Polydispersity Index     Hollow  Temperature (C)  Flowrate (ghm)  \
# 6               3.45021  13.759241              230            0.17
# 7               3.45021  17.357050              230            0.33
# 8               3.45021  19.125045              230            0.41
# 17              3.62339  28.657791              210            0.17
# 18              3.62339  29.448649              210            0.33
# 19              3.62339  27.558121              210            0.41
# 24              3.86697  22.079341              230            0.17
# 25              3.86697  23.335684              230            0.33
# 26              3.86697  24.587347              230            0.41
# 32              2.39853  26.174732              210            0.17
# 33              2.39853  26.658512              210            0.33
# 34              2.39853  26.481294              210            0.41
# 41              2.17084  14.429275              230            0.17
# 42              2.17084  18.384476              230            0.33
# 43              2.17084  19.799290              230            0.41
#
#     processtime nonDimTime  truearea
# 6      0.174532   0.004377  5.349903
# 7      0.089910   0.008497  5.184469
# 8      0.072367   0.010557  5.408054
# 17     0.174532   0.014611  5.706675
# 18     0.089910   0.028362  8.546570
# 19     0.072367   0.035237  7.127387
# 24     0.174532   0.013178  6.371682
# 25     0.089910   0.025581  5.749829
# 26     0.072367   0.031783  5.830657
# 32     0.174532   0.009167  7.434219
# 33     0.089910   0.017796  4.394051
# 34     0.072367   0.022110  6.799502
# 41     0.174532   0.005902  4.312292
# 42     0.089910   0.011456  5.226105
# 43     0.072367   0.014233  5.367192
#
# [15 rows x 40 columns]

# %%
splerp = pd.read_csv("./35denierFiberData.csv")
splerp["processtime"] = 0.029670358/splerp["Spinning Speed"]
splerp["nonDimTime"] = splerp["Relaxation Time"]/splerp["processtime"]
splerp["Relaxation Time (s)"] = splerp["Relaxation Time"]/0.159155
#print(splerp)
splerp["TotalArea"] = splerp["Average Area"]/(1-splerp["Hollow"])
splerp["Hollow"] = splerp["Hollow"]*100 
splerp["Flowrate"] = splerp["Spinning Speed"]
splerp["Color"] = 1
#splerp = splerp[(splerp.Flowrate <0.40)]
a1 = sns.relplot(
    data=splerp, kind = "scatter", hue = "Color",#style = "Relaxation Time",
    x="nonDimTime", y="Hollow",    palette = "flare",facet_kws=dict(despine=False), s = 200, edgecolor = "black", aspect = 1.15
    );

a1.set_axis_labels( "Non-Dimensional Time (-)",  "Hollow (%)", fontsize = 20)

for ax in a1.axes.ravel():
        
        ax.tick_params(which="both", right=True, labelsize = 15)
        ax.tick_params(which="both", top=True)
        ax.tick_params(which = "both",left=True, labelsize = 15)
        
#a1.set(xscale="log")
a1.set(xlim=(0.0,0.1),ylim=(11,31))        
a1.savefig("I:/My Drive/Research/NWI/Final Paper/RawData/RawFigures/HollowVsNonDIMNoColor.png", dpi = 800)
splerp.to_excel("I:/My Drive/Research/NWI/Final Paper/RawData/RawFigures/expDataOut.xlsx")

# %%
splerp = pd.read_csv("./35denierFiberData.csv")
print(splerp)
splerp["TotalArea"] = splerp["Average Area"]/(1-splerp["Hollow"])
splerp["Hollow"] = splerp["Hollow"]*100 
splerp["Flowrate"] = splerp["Spinning Speed"]
splerp["Relaxation Time"] = splerp["Relaxation Time"]/0.159155
#splerp = splerp[(splerp.Temperature ==230)]
a1 = sns.relplot(
    data=splerp, kind = "scatter", col = "Temperature", hue = "Relaxation Time",#style = "Relaxation Time",# style = "Polymer Type", #col = "Polymer Type", #col_wrap = 5, #style = "Relaxation Time",
    x="Flowrate", y="Hollow",  palette = "crest",facet_kws=dict(despine=False), s = 300, edgecolor = "black"
    );

a1.set_axis_labels( "Flowrate (g/hole*minute)",  "Hollow (%)", fontsize = 25)

for ax in a1.axes.ravel():
        
        ax.tick_params(which="both", right=True, labelsize = 20)
        ax.tick_params(which="both", top=True)
        ax.tick_params(which = "both",left=True, labelsize = 20)
        
        
a1.savefig("I:/My Drive/Research/NWI/Final Paper/RawData/RawFigures/HollowvsFlowrateConstantDenierName2.png", dpi = 600)
# Out:
#               Filename  Number of Samples Polymer Type  Temperature  \
# 0      M1-210-0,17@437                 42           M1          210
# 1   M1-210-0,25@643CFD                 34           M1          210
# 2      M1-210-0,33@848                 33           M1          210
# 3     M1-210-0,41@1054                 40           M1          210
# 4      P2-210-0,33@848                 43           P2          210
# ..                 ...                ...          ...          ...
# 69     P3-250-0,11@282                 36           P3          250
# 70     P3-250-0,17@437                 39           P3          250
# 71     P3-250-0,25@643                 32           P3          250
# 72     P3-250-0,33@848                 35           P3          250
# 73    P3-250-0,41@1054                 31           P3          250
#
#     Spinning Speed  Sample  Was CFD? Identifier  Zero Shear Viscosity  \
# 0             0.17       1         0     M1-210              352.3012
# 1             0.25       2         1     M1-210              352.3012
# 2             0.33       3         0     M1-210              352.3012
# 3             0.41       4         0     M1-210              352.3012
# 4             0.33      58         0     P2-210              240.3848
# ..             ...     ...       ...        ...                   ...
# 69            0.11      72         0     P3-250              146.2295
# 70            0.17      73         0     P3-250              146.2295
# 71            0.25      74         0     P3-250              146.2295
# 72            0.33      75         0     P3-250              146.2295
# 73            0.41      76         0     P3-250              146.2295
#
#     Relaxation Time  ...  Stdev Area  Threshold   Hollow  Average Solid Fract  \
# 0          0.001690  ...    73.89511      0.740  0.17552              0.82448
# 1          0.001690  ...    62.72260      0.705  0.21544              0.78456
# 2          0.001690  ...    78.65067      0.700  0.22133              0.77867
# 3          0.001690  ...    45.76545      0.710  0.22770              0.77230
# 4          0.001210  ...    59.71045      0.735  0.19660              0.80340
# ..              ...  ...         ...        ...      ...                  ...
# 69         0.000859  ...    90.97322      0.815  0.10053              0.89947
# 70         0.000859  ...    84.63493      0.815  0.11115              0.88885
# 71         0.000859  ...    75.62396      0.825  0.10131              0.89869
# 72         0.000859  ...    85.29134      0.820  0.10749              0.89251
# 73         0.000859  ...    64.22455      0.810  0.11361              0.88639
#
#     Stdev Solid Fract  standard error of mean    guess     error   squares  \
# 0             0.03535                 0.01069  0.20891  0.001110  0.000191
# 1             0.00814                 0.00274  0.23490  0.000379  0.002890
# 2             0.02780                 0.00949  0.24718  0.000668  0.003550
# 3             0.00945                 0.00293  0.24575  0.000326  0.004350
# 4             0.00764                 0.00228  0.18239  0.000202  0.001220
# ..                ...                     ...      ...       ...       ...
# 69            0.01333                 0.00436  0.12580  0.000639  0.003740
# 70            0.01171                 0.00368  0.13336  0.000493  0.002560
# 71            0.01107                 0.00383  0.14034  0.001520  0.003650
# 72            0.00730                 0.00242  0.14380  0.001320  0.002940
# 73            0.01256                 0.00442  0.14372  0.000906  0.002310
#
#     Why masked?
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 69          NaN
# 70          NaN
# 71          NaN
# 72          NaN
# 73          NaN
#
# [74 rows x 28 columns]
